# %% [markdown]
# # 🛒 E-Commerce Sales Analytics Dashboard
# ## Task 09 – Data Analysis & Visualization (EDA)
#
# ### 👨‍🎓 Student:
# **Mahaveer Singh**
#
# ---
#
# ## 🎯 Objective
# Analyze an E-commerce sales dataset to uncover business insights, identify sales trends, understand customer purchasing behavior, and prepare a clean dataset for Machine Learning and Streamlit Dashboard development.
#
# ---
#
# ## 🛠 Technologies Used
#
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Plotly
# - Scikit-learn
#
# ---
#
# ## 📌 Assignment Coverage
#
# ✅ Data Cleaning
#
# ✅ Exploratory Data Analysis
#
# ✅ Feature Engineering
#
# ✅ Business Insights
#
# ✅ Clean Dataset Export
#
# ⭐ Extra Enhancements:
# - Interactive Plotly Charts
# - Professional Visualizations
# - Executive Business Insights
# - Publication-Ready Notebook

# %% [markdown]
# # install Libraries

# %%
# Install required libraries
# !pip -q install plotly missingno

# %% [markdown]
# # Import Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go

import missingno as msno

from IPython.display import display

# Visualization Style
plt.style.use("ggplot")
sns.set_theme(style="whitegrid")

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv("Sample - Superstore.csv", encoding="latin1")

print("Dataset Loaded Successfully!")
# Out:
# Dataset Loaded Successfully!

# %% [markdown]
# # First Look

# %%
print("Shape:", df.shape)

df.head()
# Out:
# Shape: (9994, 21)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Last Five Rows

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # Statistical Summary

# %%
df.describe(include="all").T
# Out:
#                 count unique              top  freq          mean  \
# Row ID         9994.0    NaN              NaN   NaN        4997.5
# Order ID         9994   5009   CA-2017-100111    14           NaN
# Order Date       9994   1237         9/5/2016    38           NaN
# Ship Date        9994   1334       12/16/2015    35           NaN
# Ship Mode        9994      4   Standard Class  5968           NaN
# Customer ID      9994    793         WB-21850    37           NaN
# Customer Name    9994    793    William Brown    37           NaN
# Segment          9994      3         Consumer  5191           NaN
# Country          9994      1    United States  9994           NaN
# City             9994    531    New York City   915           NaN
# State            9994     49       California  2001           NaN
# Postal Code    9994.0    NaN              NaN   NaN  55190.379428
# Region           9994      4             West  3203           NaN
# ...

# %% [markdown]
# # Data Types

# %%
pd.DataFrame(df.dtypes, columns=["Data Type"])
# Out:
#               Data Type
# Row ID            int64
# Order ID         object
# Order Date       object
# Ship Date        object
# Ship Mode        object
# Customer ID      object
# Customer Name    object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Product ID       object
# Category         object
# Sub-Category     object
# Product Name     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64

# %% [markdown]
# # Missing Values

# %%
missing = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": round(df.isnull().mean()*100,2)
})

missing.sort_values("Missing Values", ascending=False)
# Out:
#                Missing Values  Percentage
# Row ID                      0         0.0
# Order ID                    0         0.0
# Order Date                  0         0.0
# Ship Date                   0         0.0
# Ship Mode                   0         0.0
# Customer ID                 0         0.0
# Customer Name               0         0.0
# Segment                     0         0.0
# Country                     0         0.0
# City                        0         0.0
# State                       0         0.0
# Postal Code                 0         0.0
# Region                      0         0.0
# Product ID                  0         0.0
# Category                    0         0.0
# Sub-Category                0         0.0
# Product Name                0         0.0
# Sales                       0         0.0
# Quantity                    0         0.0
# Discount                    0         0.0
# Profit                      0         0.0

# %% [markdown]
# # Missing Value Visualization

# %%
plt.figure(figsize=(10,5))
msno.matrix(df)
plt.show()

# %% [markdown]
# # Duplicate Records

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %% [markdown]
# # Remove Duplicates

# %%
df = df.drop_duplicates()

print("New Shape:", df.shape)
# Out:
# New Shape: (9994, 21)

# %% [markdown]
# # Convert Date Columns

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])

print("Date conversion completed!")
# Out:
# Date conversion completed!

# %% [markdown]
# # Feature Engineering

# %%
df["Year"] = df["Order Date"].dt.year
df["Month"] = df["Order Date"].dt.month
df["Month Name"] = df["Order Date"].dt.month_name()

df["Quarter"] = df["Order Date"].dt.quarter
df["Day"] = df["Order Date"].dt.day_name()

df["Profit Margin"] = (df["Profit"]/df["Sales"])*100

df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...     Sales  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  261.9600
# 1      Claire Gute   Consumer  United States        Henderson  ...  731.9400
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   14.6200
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  957.5775
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...   22.3680
#
# ...

# %% [markdown]
# # 📊 Exploratory Data Analysis (EDA)
#
# In this section, we analyze sales trends, customer behavior, regional performance, and profitability using professional visualizations.

# %% [markdown]
# # Monthly Sales Trend

# %%
monthly_sales = df.groupby("Month Name")["Sales"].sum().reindex([
    "January","February","March","April","May","June",
    "July","August","September","October","November","December"
])

plt.figure(figsize=(14,6))

sns.lineplot(
    x=monthly_sales.index,
    y=monthly_sales.values,
    marker="o",
    linewidth=3
)

plt.xticks(rotation=45)
plt.title("Monthly Sales Trend", fontsize=18)
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.grid(True)

plt.show()

# %% [markdown]
# # Monthly Sales (Interactive)

# %%
fig = px.line(
    monthly_sales,
    x=monthly_sales.index,
    y=monthly_sales.values,
    markers=True,
    title="Interactive Monthly Sales Trend"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Top 10 Selling Products

# %%
top_products = (
    df.groupby("Product Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(12,7))

sns.barplot(
    x=top_products.values,
    y=top_products.index
)

plt.title("Top 10 Selling Products", fontsize=18)
plt.xlabel("Sales")
plt.ylabel("Product")

plt.show()

# %% [markdown]
# # Category-wise Sales

# %%
category_sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(8,6))

plt.pie(
    category_sales,
    labels=category_sales.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Category-wise Sales")

plt.show()

# %% [markdown]
# # Sub-Category Sales

# %%
subcategory = (
    df.groupby("Sub-Category")["Sales"]
    .sum()
    .sort_values(ascending=False)
)

plt.figure(figsize=(14,7))

sns.barplot(
    x=subcategory.values,
    y=subcategory.index
)

plt.title("Sub-Category Sales")

plt.show()

# %% [markdown]
# # Regional Sales Performance

# %%
region_sales = df.groupby("Region")["Sales"].sum()

plt.figure(figsize=(8,5))

sns.barplot(
    x=region_sales.index,
    y=region_sales.values
)

plt.title("Regional Sales Performance")

plt.show()

# %% [markdown]
# # State-wise Top 10 Sales

# %%
state_sales = (
    df.groupby("State")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(12,6))

sns.barplot(
    x=state_sales.values,
    y=state_sales.index
)

plt.title("Top 10 States by Sales")

plt.show()

# %% [markdown]
# # Customer Segment Analysis

# %%
segment_sales = df.groupby("Segment")["Sales"].sum()

plt.figure(figsize=(8,5))

sns.barplot(
    x=segment_sales.index,
    y=segment_sales.values
)

plt.title("Customer Segment Analysis")

plt.show()

# %% [markdown]
# # Top 10 Customers

# %%
top_customers = (
    df.groupby("Customer Name")["Sales"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

plt.figure(figsize=(12,7))

sns.barplot(
    x=top_customers.values,
    y=top_customers.index
)

plt.title("Top 10 Customers")

plt.show()

# %% [markdown]
# # Profit by Category

# %%
profit = df.groupby("Category")["Profit"].sum()

plt.figure(figsize=(8,5))

sns.barplot(
    x=profit.index,
    y=profit.values
)

plt.title("Profit by Category")

plt.show()

# %% [markdown]
# # Discount vs Profit

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit",
    alpha=0.6
)

plt.title("Discount vs Profit")

plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.select_dtypes(include="number").corr(),
    annot=True,
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# # Sales Distribution

# %%
plt.figure(figsize=(10,6))

sns.histplot(df["Sales"], bins=40, kde=True)

plt.title("Sales Distribution")

plt.show()

# %% [markdown]
# # Profit Distribution

# %%
plt.figure(figsize=(10,6))

sns.histplot(df["Profit"], bins=40, kde=True)

plt.title("Profit Distribution")

plt.show()

# %% [markdown]
# # 💡 Executive Business Insights
#
# Based on the exploratory data analysis, the following insights summarize the key findings and business opportunities.

# %% [markdown]
# # Business Insights

# %%
print("="*70)
print("📊 EXECUTIVE BUSINESS INSIGHTS")
print("="*70)

# 1
print(f"1. Total Revenue Generated: ${df['Sales'].sum():,.2f}")

# 2
print(f"2. Total Profit Earned: ${df['Profit'].sum():,.2f}")

# 3
print(f"3. Total Orders: {df['Order ID'].nunique()}")

# 4
print(f"4. Total Customers: {df['Customer ID'].nunique()}")

# 5
print(f"5. Average Order Value: ${df['Sales'].mean():,.2f}")

# 6
print(f"6. Best Selling Category: {df.groupby('Category')['Sales'].sum().idxmax()}")

# 7
print(f"7. Most Profitable Category: {df.groupby('Category')['Profit'].sum().idxmax()}")

# 8
print(f"8. Highest Revenue Region: {df.groupby('Region')['Sales'].sum().idxmax()}")

# 9
print(f"9. Highest Profit Region: {df.groupby('Region')['Profit'].sum().idxmax()}")

# 10
print(f"10. Top Customer: {df.groupby('Customer Name')['Sales'].sum().idxmax()}")

# 11
print(f"11. Top Selling Product: {df.groupby('Product Name')['Sales'].sum().idxmax()}")

# 12
print(f"12. Highest Sales State: {df.groupby('State')['Sales'].sum().idxmax()}")

# 13
print(f"13. Highest Profit State: {df.groupby('State')['Profit'].sum().idxmax()}")

# 14
print(f"14. Highest Sales Month: {df.groupby('Month Name')['Sales'].sum().idxmax()}")

# 15
print(f"15. Average Profit Margin: {df['Profit Margin'].mean():.2f}%")
# Out:
# ...
# 📊 EXECUTIVE BUSINESS INSIGHTS
# ...
# 1. Total Revenue Generated: $2,297,200.86
# 2. Total Profit Earned: $286,397.02
# 3. Total Orders: 5009
# 4. Total Customers: 793
# 5. Average Order Value: $229.86
# 6. Best Selling Category: Technology
# 7. Most Profitable Category: Technology
# 8. Highest Revenue Region: West
# 9. Highest Profit Region: West
# 10. Top Customer: Sean Miller
# 11. Top Selling Product: Canon imageCLASS 2200 Advanced Copier
# 12. Highest Sales State: California
# 13. Highest Profit State: California
# 14. Highest Sales Month: November
# 15. Average Profit Margin: 12.03%

# %% [markdown]
# # 📈 Business Recommendations

# %%
recommendations = [
    "Increase inventory for top-selling products.",
    "Focus marketing campaigns on high-performing regions.",
    "Improve profitability of low-performing categories.",
    "Review discount strategy for low-profit products.",
    "Reward loyal customers with exclusive offers.",
    "Promote products with high profit margins.",
    "Expand operations in high-growth regions.",
    "Introduce personalized product recommendations.",
    "Optimize inventory based on monthly demand.",
    "Monitor underperforming states for targeted campaigns."
]

for i, rec in enumerate(recommendations, start=1):
    print(f"{i}. {rec}")
# Out:
# 1. Increase inventory for top-selling products.
# 2. Focus marketing campaigns on high-performing regions.
# 3. Improve profitability of low-performing categories.
# 4. Review discount strategy for low-profit products.
# 5. Reward loyal customers with exclusive offers.
# 6. Promote products with high profit margins.
# 7. Expand operations in high-growth regions.
# 8. Introduce personalized product recommendations.
# 9. Optimize inventory based on monthly demand.
# 10. Monitor underperforming states for targeted campaigns.

# %% [markdown]
# # Export Cleaned Dataset

# %%
df.to_csv("Cleaned_Superstore.csv", index=False)

print("✅ Cleaned_Superstore.csv saved successfully.")
# Out:
# ✅ Cleaned_Superstore.csv saved successfully.

# %% [markdown]
# # Download the Cleaned Dataset

# %%
from google.colab import files

files.download("Cleaned_Superstore.csv")
